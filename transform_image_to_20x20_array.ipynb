# %%
import numpy as np

# %%
from PIL import Image

# %%
img = Image.open('letters/b1.jpg')
img = img.convert('L')

# %%
image_as_array = np.array(img)

# %%
print(image_as_array)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image_as_array, cmap='gray', interpolation='nearest')

# %%
img.thumbnail((20, 20), Image.ANTIALIAS)

# %%
image_as_array = np.array(img)

# %%
plt.imshow(image_as_array, cmap='gray', interpolation='nearest')

# %% [markdown]
# ## With Letter M

# %%
img = Image.open('letters/m1.jpeg')
img = img.convert('L')

# %%
image_as_array = np.array(img)
plt.imshow(image_as_array, cmap='gray', interpolation='nearest')

# %%
img.thumbnail((20, 20), Image.ANTIALIAS)
image_as_array = np.array(img)
plt.imshow(image_as_array, cmap='gray', interpolation='nearest')

# %% [markdown]
# ## With letter S

# %%
img = Image.open('letters/s1.jpg')
img = img.convert('L')
image_as_array = np.array(img)
plt.imshow(image_as_array, cmap='gray', interpolation='nearest')

# %%
img.thumbnail((20, 20), Image.ANTIALIAS)
image_as_array = np.array(img)
plt.imshow(image_as_array, cmap='gray', interpolation='nearest')
